# %% [markdown]
# <a href="https://colab.research.google.com/github/jathurwa/mypython/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: a python code to convert audio speech into text

# !pip install SpeechRecognition
import speech_recognition

# Initialize the recognizer
recognizer = speech_recognition.Recognizer()

# Open the audio file
with speech_recognition.AudioFile('audio.wav') as source:
  audio = recognizer.record(source)

# Recognize the speech
text = recognizer.recognize_google(audio)

# Print the transcribed text
print(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5607345b074b> in <cell line: 3>()
#       1 # prompt: a python code to convert audio speech into text
#       2
# ----> 3 import speech_recognition as sr
#       4
#       5 # Create a speech recognition object
#
# ModuleNotFoundError: No module named 'speech_recognition'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install speechrecognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 29.0 MB/s eta 0:00:00
# ...

# %%
# prompt: a python code to convert audio speech into text

# !pip install SpeechRecognition
import speech_recognition

# Initialize the recognizer
recognizer = speech_recognition.Recognizer()

# Open the audio file
with speech_recognition.AudioFile('audio.wav') as source:
  audio = recognizer.record(source)

# Recognize the speech
text = recognizer.recognize_google(audio)

# Print the transcribed text
print(text)
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2142759dcc27> in <cell line: 10>()
#       8
#       9 # Open the audio file
# ---> 10 with speech_recognition.AudioFile('audio.wav') as source:
#      11   audio = recognizer.record(source)
#      12
#
# /usr/local/lib/python3.10/dist-packages/speech_recognition/__init__.py in __enter__(self)
#     239         try:
#     240             # attempt to read the file as WAV
# --> 241             self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#     242             self.little_endian = True  # RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#     243         except (wave.Error, EOFError):
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# ...

# %%
# pip installing necessary libraries
# pip install pandas
# pip install numpy
# pip install matplotlib
# pip install seaborn
pip install pandas
pip install numpy
pip install matplotlib
pip install seaborn
# Out:
#   File "<ipython-input-4-8664ad39330e>", line 6
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
pip install pandas

# %%
pip install numpy

# %%
pip install matplotlib

# %%
pip install seaborn

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <!-- loading the files -->

# %%
dataframe = pd.read_csv(r"D:\data\zomato.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-7a8b61a7ffed> in <cell line: 1>()
# ----> 1 dataframe = pd.read_csv(r"D:\data\zomato.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...

# %%
dataframe = pd.read_csv("D:\data\zomato.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-467d81732e59> in <cell line: 1>()
# ----> 1 dataframe = pd.read_csv("D:\data\zomato.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...

# %%
dataframe = pd.read_csv(r"D:\data\zomato.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-a2cf0f002a43> in <cell line: 1>()
# ----> 1 dataframe = pd.read_csv(r"D:\data\zomato.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...

# %%
dataframe = pd.read_csv("D:/data/zomato.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-df47802c5138> in <cell line: 1>()
# ----> 1 dataframe = pd.read_csv("D:/data/zomato.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import os
print(os.listdir("D:/data/zomato.csv"))  # Adjust the path if necessary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-0c78a84b8285> in <cell line: 2>()
#       1 import os
# ----> 2 print(os.listdir("D:/data/zomato.csv"))  # Adjust the path if necessary
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/data/zomato.csv'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3a3d0db-177e-495a-9d95-3c4c22295bbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3a3d0db-177e-495a-9d95-3c4c22295bbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataframe= pd.read_csv("zomato.csv")

# %%
df = pd.read_csv(r"zomato.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-83b3d8607805> in <cell line: 1>()
# ----> 1 dataframe = pd.read_csv(r"zomato.csv")
#
# NameError: name 'pd' is not defined

# %%
print (dataframe)
# Out:
#       Unnamed: 0.1  Unnamed: 0         restaurant name     restaurant type  \
# 0                0           0            #FeelTheROLL         Quick Bites
# 1                1           1              #L-81 Cafe         Quick Bites
# 2                2           2                 #refuel                Cafe
# 3                3           3      '@ Biryani Central       Casual Dining
# 4                4           4              '@ The Bbq       Casual Dining
# ...            ...         ...                     ...                 ...
# 7100          7100        7100                  Zoey's                Cafe
# 7101          7101        7101  ZOROY Luxury Chocolate      Dessert Parlor
# 7102          7102        7102       Zu's Doner Kebaps  Takeaway, Delivery
# 7103          7103        7103                   Zyara       Casual Dining
# 7104          7104        7104                  Zyksha          Food Truck
#
# ...

# %%
print(dataframe.head(10))
# Out:
#    Unnamed: 0.1  Unnamed: 0                       restaurant name  \
# 0             0           0                          #FeelTheROLL
# 1             1           1                            #L-81 Cafe
# 2             2           2                               #refuel
# 3             3           3                    '@ Biryani Central
# 4             4           4                            '@ The Bbq
# 5             5           5                                  '@99
# 6             6           6                               '@Italy
# 7             7           7                  '@North Parontha Hut
# 8             8           8                              1000 B.C
# 9             9           9  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
#
#       restaurant type  rate (out of 5)  num of ratings  avg cost (two people)  \
# 0         Quick Bites              3.4               7                  200.0
# 1         Quick Bites              3.9              48                  400.0
# ...

# %%
print (dataframe.tail(10))
# Out:
#       Unnamed: 0.1  Unnamed: 0                          restaurant name  \
# 7095          7095        7095                                  Zingron
# 7096          7096        7096                        Ziyan's Cafe 27th
# 7097          7097        7097                                   Zodiac
# 7098          7098        7098  Zodiac - Fortune Select JP Cosmos Hotel
# 7099          7099        7099                            Zodiac Grills
# 7100          7100        7100                                   Zoey's
# 7101          7101        7101                   ZOROY Luxury Chocolate
# 7102          7102        7102                        Zu's Doner Kebaps
# 7103          7103        7103                                    Zyara
# 7104          7104        7104                                   Zyksha
#
#          restaurant type  rate (out of 5)  num of ratings  \
# 7095       Casual Dining              4.0             510
# ...

# %%
# show number of rows and columns
print(dataframe.shape)
# Out:
# (7105, 12)

# %%
# summary stastics 4 numerical column
dataframe.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0  rate (out of 5)  num of ratings  \
# count   7105.000000  7105.000000      7037.000000     7105.000000
# mean    3552.000000  3552.000000         3.514253      188.921042
# std     2051.181164  2051.181164         0.463249      592.171049
# min        0.000000     0.000000         1.800000        1.000000
# 25%     1776.000000  1776.000000         3.200000       16.000000
# 50%     3552.000000  3552.000000         3.500000       40.000000
# 75%     5328.000000  5328.000000         3.800000      128.000000
# max     7104.000000  7104.000000         4.900000    16345.000000
#
#        avg cost (two people)
# count            7048.000000
# mean              540.286464
# std               462.902305
# min                40.000000
# 25%               300.000000
# 50%               400.000000
# 75%               600.000000
# max              6000.000000

# %%
# index
print (dataframe.index)
# Out:
# RangeIndex(start=0, stop=7105, step=1)

# %%
# identify missing values
print(dataframe.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed506fd66e0a> in <cell line: 2>()
#       1 # identify missing values
# ----> 2 print(dataframe.isnull().sum())
#
# NameError: name 'dataframe' is not defined

# %%
print(dataframe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5674f2920008> in <cell line: 1>()
# ----> 1 print(dataframe)
#
# NameError: name 'dataframe' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9047c419-89eb-439c-afc6-a9598e1c251e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9047c419-89eb-439c-afc6-a9598e1c251e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataframe = pd.read_csv("zomato.csv")

# %%
dataframe.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
dataframe.tail()
# Out:
#       Unnamed: 0.1  Unnamed: 0         restaurant name     restaurant type  \
# 7100          7100        7100                  Zoey's                Cafe
# 7101          7101        7101  ZOROY Luxury Chocolate      Dessert Parlor
# 7102          7102        7102       Zu's Doner Kebaps  Takeaway, Delivery
# 7103          7103        7103                   Zyara       Casual Dining
# 7104          7104        7104                  Zyksha          Food Truck
#
#       rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 7100              4.3             894                  600.0          Yes
# 7101              4.0              68                  250.0          Yes
# 7102              3.7              33                  350.0           No
# 7103              3.8             191                  650.0          Yes
# 7104              3.4               9                  200.0           No
#
# ...

# %%
dataframe. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           7105 non-null   int64
#  1   Unnamed: 0             7105 non-null   int64
#  2   restaurant name        7105 non-null   object
#  3   restaurant type        7105 non-null   object
#  4   rate (out of 5)        7037 non-null   float64
#  5   num of ratings         7105 non-null   int64
#  6   avg cost (two people)  7048 non-null   float64
#  7   online_order           7105 non-null   object
#  8   table booking          7105 non-null   object
#  9   cuisines type          7105 non-null   object
#  10  area                   7105 non-null   object
#  11  local address          7105 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 666.2+ KB

# %%
# number of rows & colum
print(dataframe.shape)
# Out:
# (7105, 12)

# %%
# summary statisticaly for numerical colum
dataframe.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0  rate (out of 5)  num of ratings  \
# count   7105.000000  7105.000000      7037.000000     7105.000000
# mean    3552.000000  3552.000000         3.514253      188.921042
# std     2051.181164  2051.181164         0.463249      592.171049
# min        0.000000     0.000000         1.800000        1.000000
# 25%     1776.000000  1776.000000         3.200000       16.000000
# 50%     3552.000000  3552.000000         3.500000       40.000000
# 75%     5328.000000  5328.000000         3.800000      128.000000
# max     7104.000000  7104.000000         4.900000    16345.000000
#
#        avg cost (two people)
# count            7048.000000
# mean              540.286464
# std               462.902305
# min                40.000000
# 25%               300.000000
# 50%               400.000000
# 75%               600.000000
# max              6000.000000

# %%
# index details
print(dataframe.index)
# Out:
# RangeIndex(start=0, stop=7105, step=1)

# %%
# column names
print(dataframe.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'restaurant name', 'restaurant type',
#        'rate (out of 5)', 'num of ratings', 'avg cost (two people)',
#        'online_order', 'table booking', 'cuisines type', 'area',
#        'local address'],
#       dtype='object')

# %%
# applying functions to each coulmn
dataframe.apply(np.max)
# Out:
# Unnamed: 0.1                                                     7104
# Unnamed: 0                                                       7104
# restaurant name          re:cess - Hilton Bangalore Embassy GolfLinks
# restaurant type                                    Takeaway, Delivery
# rate (out of 5)                                                   4.9
# num of ratings                                                  16345
# avg cost (two people)                                          6000.0
# online_order                                                      Yes
# table booking                                                     Yes
# cuisines type                     Vietnamese, Thai, Burmese, Japanese
# area                                                       Whitefield
# local address                                             Yeshwantpur
# dtype: object

# %%
dataframe.apply(np.min)
# Out:
# Unnamed: 0.1                           0
# Unnamed: 0                             0
# restaurant name             #FeelTheROLL
# restaurant type                   Bakery
# rate (out of 5)                      1.8
# num of ratings                         1
# avg cost (two people)               40.0
# online_order                          No
# table booking                         No
# cuisines type            African, Burger
# area                        Banashankari
# local address                        BTM
# dtype: object

# %%
dataframe.apply(np.cumsum)
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                3           3
# 3                6           6
# 4               10          10
# ...            ...         ...
# 7100      25208550    25208550
# 7101      25215651    25215651
# 7102      25222753    25222753
# 7103      25229856    25229856
# 7104      25236960    25236960
#
#                                         restaurant name  \
# 0                                          #FeelTheROLL
# 1                                #FeelTheROLL#L-81 Cafe
# 2                         #FeelTheROLL#L-81 Cafe#refuel
# 3       #FeelTheROLL#L-81 Cafe#refuel'@ Biryani Central
# 4     #FeelTheROLL#L-81 Cafe#refuel'@ Biryani Centra...
# ...                                                 ...
# 7100  #FeelTheROLL#L-81 Cafe#refuel'@ Biryani Centra...
# 7101  #FeelTheROLL#L-81 Cafe#refuel'@ Biryani Centra...
# 7102  #FeelTheROLL#L-81 Cafe#refuel'@ Biryani Centra...
# ...

# %%
dataframe.isnull().sum()
# Out:
# Unnamed: 0.1              0
# Unnamed: 0                0
# restaurant name           0
# restaurant type           0
# rate (out of 5)          68
# num of ratings            0
# avg cost (two people)    57
# online_order              0
# table booking             0
# cuisines type             0
# area                      0
# local address             0
# dtype: int64

# %%
# removing the missing values
dataframe.dropna(inplace=True)

# %%
# start of visualization
# Drawing line Graph
restaurant= dataframe.groupby('restaurant name').size()
print(restaurant)
# Out:
# restaurant name
# #FeelTheROLL                                    1
# #L-81 Cafe                                      1
# #refuel                                         1
# '@ Biryani Central                              1
# '@ The Bbq                                      1
#                                                ..
# i-Bar - The Park Bangalore                      1
# iFruit Live Ice Creams                          1
# iSpice Resto Cafe                               1
# nu.tree                                         1
# re:cess - Hilton Bangalore Embassy GolfLinks    1
# Length: 6984, dtype: int64

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
result = grouped_data.sort_values(ascending=False)
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9540deb6c38f> in <cell line: 1>()
# ----> 1 grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
#       2 result = grouped_data.sort_values(ascending=False)
#       3 print(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8250         axis = self._get_axis_number(axis)
#    8251
# -> 8252         return DataFrameGroupBy(
#    8253             obj=self,
#    8254             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     929
#     930         if grouper is None:
# --> 931             grouper, exclusions, obj = get_grouper(
# ...

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
result = pd.dataframe({})
